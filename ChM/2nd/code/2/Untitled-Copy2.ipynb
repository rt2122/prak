# %%
import pandas as pd
import matplotlib.pyplot as plt

res = pd.read_csv("ans.txt", names=["x", "y"], index_col=False)
#true = pd.read_csv("true0.txt", names=["x", "y"], index_col=False)

# %%
plt.figure(figsize = (15, 10))
plt.plot(res["x"], res["y"])
#plt.plot(true["x"], true["y"], 'r-')
