# %%
import pandas as pd
import matplotlib.pyplot as plt

res = pd.read_csv("res.txt", names=["x", "y"], index_col=False)
true = pd.read_csv("true.txt", names=["x", "y"], index_col=False)

# %%
plt.plot(res["x"], res["y"])
plt.plot(true["x"], true["y"], 'r-')
