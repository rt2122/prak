# %%
import pandas as pd
import matplotlib.pyplot as plt

u = pd.read_csv("u.txt", names=["x", "y"], index_col=False)
tu = pd.read_csv("tu.txt", names=["x", "y"], index_col=False)
v = pd.read_csv("v.txt", names=["x", "y"], index_col=False)
tv = pd.read_csv("tv.txt", names=["x", "y"], index_col=False)

# %%
plt.figure(figsize = (15, 10))
plt.plot(u["x"], u["y"])
plt.plot(tu["x"], tu["y"], 'r-')

# %%
plt.figure(figsize = (15, 10))
plt.plot(v["x"], v["y"])
plt.plot(tv["x"], tv["y"], 'r-')

# %%
plt.figure(figsize = (15, 10))
plt.plot(u["x"], u["y"])
plt.plot(v["x"], v["y"], 'r-')
