# %% [markdown]
# #### Часть 4: исследование скорости настройки от количества данных.
# Далее посмотрим, как изменяется время работы функций KMeans4 и best_K в зависимости от количества заданных точек. <br>
# *Испытания функции KMeans4:*

# %%
from mylib import *

# %%
pylab.figure(0, figsize = (15, 10))
test_time(k_start = 2, k_end = 10, n_start = 200, n_end = 2000, n_tests = 20, times = 5)

# %%
pylab.figure(0, figsize = (15, 10))
test_time(k_start = 2, k_end = 20, n_start = 2000, n_end = 10000, n_tests = 20, times = 1)

# %% [markdown]
# Последний график оказался таким "неровным" из-за того, что для каждой пары n и k испытание проводилось лишь однажды, поэтому общие закономерности не так хорошо видны. Однако вычисление времени работы функции несколько раз для каждой пары n и k заняло бы слишком много времени (общее время работы всех испытаний больше двойного интеграла графика функции, приведенной выше). <br><br>
# Испытания функции best_K:

# %%
pylab.figure(0, figsize = (8, 8))
test_time_best_K(n_start = 200, n_end = 2000, n_tests = 16, times = 4)

# %%
pylab.figure(0, figsize = (8, 8))
test_time_best_K(n_start = 2000, n_end = 8000, n_tests = 10, times = 1)

# %% [markdown]
# С увеличением числа точек растет время работы функции best_K, для количества точек более 1000 время будет превышать 7 минут.
